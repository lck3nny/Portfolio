# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %% [markdown]
# #hello

# %%
my_snkrs = pd.read_csv("SneakerStocks.csv")
my_snkrs = my_snkrs[:-2]
my_snkrs.head(20)
# Out:
#                Model                   Brand   Size         Colorway  \
# 0           Jordan 1               Nike x OW    US9              UNC
# 1           Jordan 1                    Nike    US9      Turbo Green
# 2           Jordan 1  Nike x Nigel Sylvester    US9            Cream
# 3          LD Waffle            Nike X Sacai    US9             Blue
# 4   React Element 85       Nike X Unvercover    US9             Volt
# 5   React Element 85                    Nike    US9             Sail
# 6         Presto Mid           Nike X ACRNYM    US9            Black
# 7          Yeezy 500                  Adidas  US9.5            Black
# 8               AF-1               Nike X OW    US9             Volt
# 9         Blazer Mid               Nike X OW    US9          Vanilla
# 10        Blazer Mid               Nike X OW  US8.5            Black
# 11         LD Waffle            Nike X Sacai    US9            Green
# 12       SB Dunk Low         Nike SB X Parra    US9            Multi
# ...

# %%
color_0 = '#303030'
color_1 = '#E26C32'
color_2 = '#8CE5CF'
colors = []
for idx, row in my_snkrs.iterrows():
    if(row['Profit'] < 0):
        colors.append("b")
        colors.append("g")
    else:
        colors.append("b")
        colors.append("r")
        
print(colors)
# Out:
# ['b', 'r', 'b', 'r', 'b', 'r', 'b', 'r', 'b', 'r', 'b', 'r', 'b', 'r', 'b', 'r', 'b', 'r', 'b', 'r', 'b', 'r', 'b', 'r', 'b', 'r', 'b', 'g', 'b', 'r', 'b', 'r', 'b', 'r', 'b', 'r', 'b', 'r', 'b', 'r']

# %%
x = np.arange(10)
# Out:
# 2

# %%
x = np.arange(10)
y = np.arange(10) * 0.1

col = []
for val in y:
    if val < 0.4:
        col.append('blue')
    else:
        col.append('red')

# col looks like this: ['blue', 'blue', 'blue', 'blue', 'red', 'red', 'red', 'green', 'green', 'green']

plt.barh(x, y, color = col)
# Out:
# <BarContainer object of 10 artists>

# %%
colors = [['#303030',
          '#303030',
          '#303030',
          '#303030',
          '#303030',
          '#303030',
          '#303030',
          '#303030',
          '#303030',
          '#303030',
          '#303030',
          '#303030',
          '#303030',
          '#303030',
          '#303030',
          '#303030',
          '#303030',
          '#303030',
          '#303030',
          '#303030'],['#8CE5CF',
                     '#8CE5CF',
                     '#8CE5CF',
                     '#8CE5CF',
                     '#E26C32',
                     '#E26C32',
                     '#E26C32',
                     '#E26C32',
                     '#E26C32',
                     '#E26C32',
                     '#E26C32',
                     '#E26C32',
                     '#E26C32',
                     '#E26C32',
                     '#E26C32',
                     '#E26C32',
                     '#E26C32',
                     '#E26C32',
                     '#E26C32',
                     '#E26C32']]

# %%
df = pd.DataFrame({'Price Paid': list(my_snkrs['Price Paid (CAD)']),
                  'Market Value': list(my_snkrs['Current Val (CAD)'] - my_snkrs['Price Paid (CAD)'])}, 
                  index= list(my_snkrs['Brand'] + " " + my_snkrs['Model'] ))



ax = paid_vs_val.plot.barh(stacked=False, figsize=(15,8), color=[[], []])
ax.xaxis.set_major_formatter('${x:1.0f}')
plt.savefig('snkrs_profit.png')

# %%
# Out:
# 180
