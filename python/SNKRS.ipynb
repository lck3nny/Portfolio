# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import numpy as np

# %% [markdown]
# # Market Value vs Price Paid
#
# The below graph shows the price paid for each sneaker vs the current market value (or value of sale).
# All profits are marked in blue, with losses marked in orage.

# %%
col_1 = "#8CE5CF"
col_2 = "#E47736"

col_4 = "#303030"

# %%
col_cv = []
col_pp = []
for x, row in my_snkrs.iterrows():
    if(row['Profit'] >= 0):
        col_cv.append(col_1)
        col_pp.append(col_4)
    else:
        col_cv.append(col_2)
        col_pp.append(col_4)

# %%
extra = Rectangle((0, 0), 1, 1, fc="w", fill=False, edgecolor='none', linewidth=0)
ax.legend([extra, bar_0_10, bar_10_100], ("My explanatory text", "0-10", "10-100"))
plt.show()

# %%
N = len(my_snkrs.index)

current_val = list(my_snkrs['Current Val (CAD)'])

ind = np.arange(N)  # the x locations for the groups
width = 0.25       # the width of the bars

fig, ax = plt.subplots(figsize=(15,8))

rects1 = ax.barh(ind, current_val, width, color=col_cv)


price_paid = list(my_snkrs['Price Paid (CAD)'])

rects2 = ax.barh(ind + width, price_paid, width, color=col_mp)

# add some text for labels, title and axes ticks
ax.xaxis.set_major_formatter('${x:1.0f}')
ax.set_yticks(np.arange(N))
ax.set_yticklabels(list(my_snkrs['Brand'] + " " + my_snkrs['Model'] ))

extra = Rectangle((0, 0), 1, 1, fc=col_2, fill=True, edgecolor='none', linewidth=0)

# ax.legend((rects1[0], rects2[0]), ('Market Value (profit)', 'Price Paid'))
ax.legend((rects1[0], extra, rects2[0]), ('Market Value (profit)', 'Market Value (loss)', 'Price Paid'))


plt.savefig("sneaker_stocks.png")
plt.show()
